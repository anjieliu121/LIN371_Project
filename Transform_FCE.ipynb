# %% [markdown]
# # transform raw FCE data into CSV
# * no need to modify this file unless we need to change the database structure

# %% [markdown]
# ### Manually checked documents:
# * doc2.xml
# * doc865.xml (did not check essays)

# %%
import xml.etree.ElementTree as ET
import re
import os
import pandas as pd
import numpy as np

# %%
directory = "raw_data/fce-released-dataset/dataset/"

# %%
"""
Assumptions: 
Everyone uses punctuation with correct spacing. (i.e. no white space in front of a punctuation.)
Spacing in front of each paragraph is ignored. (i.e. all sentences are left indented.)
Every document has similar XML structures.
"""
def get_coded_answer(paragraphs, debug=False):
    result = []
    mistakes = []
    for p in paragraphs:
        sentence = [p.text.strip() + ' '] if p.text else []
        for ns in p:
            mistakes.append(ns.attrib.get('type'))
            for child in ns:
                all_incorrect_text = []
                if child.tag == 'i' and child.text is not None:
                    incorrect_text = child.text.strip();
                    all_incorrect_text.append(incorrect_text + ' ')
                    current = child
                    while current:
                        current = current.find('./NS/i')
                        if current is not None and current.text is not None:
                            incorrect_text = current.text.strip()
                            all_incorrect_text.append(incorrect_text + ' ')
                    sentence.append(''.join(all_incorrect_text) + '')
            if ns.tail:
                p_tail = ns.tail.strip();
                sentence.append(p_tail + ' ')
        sentence = ''.join(sentence)
        sentence = ' '.join([word.strip() for word in sentence.split()])
        sentence = re.sub(r'\s+([.,!?;:])', r'\1', sentence)
        result.append(sentence)
        if debug:
            print("__________________________________________________________________________")
            print(sentence)
    return '\n'.join(result), mistakes

# %%
"""
add 1 XML file to df
"""
def add_XML(dir, df, debug=False):
    student = {"ID": '/'.join(dir.split("/")[-2:])}
    # Load the XML file
    tree = ET.parse(dir) 
    root = tree.getroot()
    
    # Candidate information
    candidate = root.find('.//candidate')
    student['native_language'] = candidate.find('./personnel/language').text
    student['age'] = candidate.find('./personnel/age').text if candidate.find('./personnel/age') is not None else np.nan
    student['total_score'] = candidate.find('./score').text
    
    
    # Test Answer 1
    new_row = student.copy()
    answer = root.find('.//text/answer1')
    new_row["question_number"] = answer.find('./question_number').text
    new_row["exam_score"] = answer.find('./exam_score').text if answer.find('./exam_score') is not None else np.nan
    new_row["answer"], new_row["mistakes_tag"] = get_coded_answer(answer.find('./coded_answer'), debug=False)
    df.loc[len(df)] = new_row
    
    # debug
    if debug:
        print(f'Native Language: {student["native_language"]}, Age: {student["age"]}, Total Score: {student["total_score"]}')
        print(f'----Question Number: {new_row["question_number"]}, Exam Score: {new_row["exam_score"]}')
        print(f'----Coded Answer: \n{new_row["answer"]}')
    
    
    # Test Answer 2
    new_row = student.copy()
    answer = root.find('.//text/answer2')
    if answer is not None:
        new_row["question_number"] = answer.find('./question_number').text
        new_row["exam_score"] = answer.find('./exam_score').text if answer.find('./exam_score') is not None else np.nan
        new_row["answer"], new_row["mistakes_tag"] = get_coded_answer(answer.find('./coded_answer'), debug=False)
        df.loc[len(df)] = new_row
        
        # debug
        if debug:
            print(f'----Question Number: {new_row["question_number"]}, Exam Score: {new_row["exam_score"]}')
            print(f'----Coded Answer: \n{new_row["answer"]}')
    
    return df

# %%
"""
sort directories in custom order
"""
def sort_key(file_path):
    match = re.search(r'/(\d+)_(\d+)_(\d+)/doc(\d+)\.xml$', file_path)
    if match:
        return int(match.group(1)), int(match.group(2)), int(match.group(3)), int(match.group(4))
    return float('inf'), float('inf'), float('inf'), float('inf')

# %%
"""
Example: doc2.xml
"""
dir = f'{directory}/0100_2000_6/doc2.xml'
df = pd.DataFrame(columns=['ID', 'native_language','age', 'total_score', 'question_number', 'exam_score', 'answer', 'mistakes_tag'])

add_XML(dir, df, debug=True)
# Out:
# Native Language: Chinese, Age: 16-20, Total Score: 24.0
# ----Question Number: 1, Exam Score: 3.2
# ----Coded Answer:
# Dear Mr Ryan.
# Thanks for you letter. I am so exciting that I have won the first prize. I will give you all information you need and ask some questions.
# I could only travel on July. As you know, I am a student and the nearest holiday is summer holiday. But I have booked a flight to home at the beginning of Auguest. And also I would like to go on summer.
# The accommodation I would like to live in tents. Because I never live in tents before. I think it is great and I want to try it.
# I like doing sports. I would like to play basketball and golf when I am at the Camp. I play basketball a lot and I am a member of our college term. But I am not very good at golf.
# And also I want to ask some questions. What clothes should I taken? How much money should I taken? And how could we meet at the airport? I am looking forward your reply.
# Yours sincerely.
# ----Question Number: 2, Exam Score: 2.3
# ----Coded Answer:
# As our class is going to mark a short video about daily life at college, I write this report to suggest some lessons and activities which should be filmed.
# 1. English lesson. Because all students in English class are from all over the world. We can talk everybody's feeling living and study at a foreign country.
# 2. Computing lesson and computer room. Nowdays internet makes us closer and closer. We can get all what we want on internet. It's one of the most important things in our life now.
# 3. Liabrary. We not only borrow books from liabrary but also study at liabrary. Library is very important in our daily life.
# 4. Canteen. Everyday we go to canteen have lunch, no matter you bought food from there or you take your own food.
# 5. Football. What do you do after class? Joging or doing some sports? You can't forget football.
# These are what I think should be filmed. If any of you have other suggestion, we can discuss again. But I think these five lesson or activities are most common in our daily life at college.
#                      ID native_language    age total_score question_number  \
# 0  0100_2000_6/doc2.xml         Chinese  16-20        24.0               1
# 1  0100_2000_6/doc2.xml         Chinese  16-20        24.0               2
#
#   exam_score                                             answer  \
# 0        3.2  Dear Mr Ryan.\nThanks for you letter. I am so ...
# 1        2.3  As our class is going to mark a short video ab...
#
#                                         mistakes_tag
# 0  [RP, DD, RJ, MD, TV, RT, MD, UT, S, RT, MT, MP...
# 1  [RV, TV, UQ, MD, RP, MT, FN, MT, FV, RT, S, MD...

# %%
"""
sort directories into the given order
"""
directories = []
for subdir, dirs, files in os.walk(directory):
    for file in files:
        directories.append(os.path.join(subdir, file))

directories = sorted(directories, key=sort_key)
print(directories)
# Out:
# ['raw_data/fce-released-dataset/dataset/0100_2000_6/doc2.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc4.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc6.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc11.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc15.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc24.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc27.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc34.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc41.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc48.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc49.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc50.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc57.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc58.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc59.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc61.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc64.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc66.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc67.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc72.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc75.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc82.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc83.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc84.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc85.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc93.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc105.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc109.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc119.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc142.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc148.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc161.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc164.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc165.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc166.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc168.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc169.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc173.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc174.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc176.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc181.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc183.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc186.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc202.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc207.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc215.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc231.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc234.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc243.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc244.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc247.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc268.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc277.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc280.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc282.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc286.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc297.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc310.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc315.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc319.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc325.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc326.xml', 'raw_data/fce-released-dataset/dataset/0100_2000_6/doc330.xm ...

# %%
"""
OMG I DID IT
"""
df = pd.DataFrame(columns=['ID', 'native_language','age', 'total_score', 'question_number', 'exam_score', 'answer', 'mistakes_tag'])

for dir in directories:
    df = add_XML(dir, df)

df
# Out:
#                             ID native_language    age total_score  \
# 0         0100_2000_6/doc2.xml         Chinese  16-20        24.0
# 1         0100_2000_6/doc2.xml         Chinese  16-20        24.0
# 2         0100_2000_6/doc4.xml         Chinese  21-25        17.0
# 3         0100_2000_6/doc4.xml         Chinese  21-25        17.0
# 4         0100_2000_6/doc6.xml          Polish  16-20        26.0
# ...                        ...             ...    ...         ...
# 2476   0102_2001_6/doc3139.xml        Japanese  26-30       36.00
# 2477  0102_2001_12/doc2871.xml          Polish  26-30       40.00
# 2478  0102_2001_12/doc2871.xml          Polish  26-30       40.00
# 2479  0102_2001_12/doc2894.xml         Russian  16-20       40.00
# 2480  0102_2001_12/doc2894.xml         Russian  16-20       40.00
#
#      question_number exam_score  \
# 0                  1        3.2
# 1                  2        2.3
# 2                  1        2.2
# 3                  3        2.1
# 4                  1        3.1
# ...              ...        ...
# 2476               3        4.3
# 2477               1        5.3
# 2478               3        5.2
# 2479               1        5.3
# 2480               4        5.3
#
#                                                  answer  \
# 0     Dear Mr Ryan.\nThanks for you letter. I am so ...
# 1     As our class is going to mark a short video ab...
# 2     Dear Madam Helen Ryan,\nI have received your l...
# 3     I agree! Sometimes shopping is not always enjo...
# 4     Dir Madam\nI'm writing to you in reply to your...
# ...                                                 ...
# 2476  I had never taken birthdays serious, both my o...
# 2477  Dear Mary,\nI'm really happy to hear from you!...
# 2478  It was three o'clock in the morning when the p...
# 2479  Dear John!\nI was very happy to receive your l...
# 2480  TV - a powerful force that keeps us glued to i...
#
#                                            mistakes_tag
# 0     [RP, DD, RJ, MD, TV, RT, MD, UT, S, RT, MT, MP...
# 1     [RV, TV, UQ, MD, RP, MT, FN, MT, FV, RT, S, MD...
# 2     [RN, TV, RY, AGV, MA, W, R, MT, RC, RA, MD, RP...
# 3     [UT, U, RP, MP, L, RT, UT, FV, R, RV, R, RN, T...
# 4     [S, S, S, RT, SX, RP, S, MT, FV, RD, S, S, RT,...
# ...                                                 ...
# 2476        [DY, RQ, RC, MA, FD, RV, AGA, S, FN, L, RT]
# 2477                               [TV, RP, MD, RC, RP]
# 2478                       [RD, TV, FV, RD, MY, TV, TV]
# 2479  [UP, RP, RJ, RP, S, R, TV, RD, MD, MD, RP, RP,...
# 2480  [RA, RP, ID, W, RP, MP, MD, UY, TV, AGA, TV, U...
#
# [2481 rows x 8 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
#                             ID native_language    age total_score  \
# 308     0100_2000_6/doc865.xml          French    NaN        25.0
# 309     0100_2000_6/doc865.xml          French    NaN        25.0
# 390    0100_2000_6/doc1153.xml         Spanish    NaN        24.0
# 391    0100_2000_6/doc1153.xml         Spanish    NaN        24.0
# 392    0100_2000_6/doc1157.xml          Korean    NaN        32.0
# 393    0100_2000_6/doc1157.xml          Korean    NaN        32.0
# 997    0100_2000_12/doc548.xml        Japanese  26-30       27.00
# 1111  0100_2000_12/doc1581.xml         Turkish  21-25       25.00
# 1162  0100_2000_12/doc2302.xml          German  16-20       37.00
# 1281   0100_2001_6/doc3063.xml          German    NaN       26.00
# 1282   0100_2001_6/doc3063.xml          German    NaN       26.00
# 1629    0102_2000_6/doc883.xml           Greek    NaN        34.0
# 1630    0102_2000_6/doc883.xml           Greek    NaN        34.0
# 1997   0102_2000_6/doc2009.xml         Chinese  16-20        27.0
# 2052   0102_2000_6/doc2197.xml           Greek    NaN        30.0
# 2053   0102_2000_6/doc2197.xml           Greek    NaN        30.0
# 2317   0102_2000_12/doc180.xml          German    NaN       25.00
# 2318   0102_2000_12/doc180.xml          German    NaN       25.00
# 2336   0102_2000_12/doc284.xml          Korean  21-25       23.00
# 2383   0102_2000_12/doc599.xml        Japanese  16-20       24.00
# 2384   0102_2000_12/doc599.xml        Japanese  16-20       24.00
# 2428  0102_2000_12/doc1579.xml          French  16-20       31.00
#
#      question_number exam_score  \
# 308                1        2.3
# 309                3        3.2
# 390                1        3.1
# 391                4        3.1
# 392                1        4.2
# 393                4        4.1
# 997                2        NaN
# 1111               3        NaN
# 1162              5b        NaN
# 1281               1        3.3
# 1282               3        3.1
# 1629               1        3.3
# 1630               3        4.3
# 1997               4        NaN
# 2052               1        4.2
# 2053               3        3.3
# 2317               1        3.1
# 2318               4        3.2
# 2336               3        NaN
# 2383               1        NaN
# 2384               2        NaN
# 2428               4        NaN
#
#                                                  answer  \
# 308   Misses Helen Ryan,\nFirst of all I would like ...
# 309   Shopping is not always enjoyable.\nHowever it ...
# 390   Hi Helen,\nIm very excited because I won the f...
# 391   Dear Kim Im having a great time here in brazil...
# 392   Dear Sir/Madam,\nI am writing in order to give...
# 393   Dear Kim,\nHow are you? Thanks for your last l...
# 997   Some people said that famous people such as po...
# 1111  Futuristic Designs Of People's Homes\nTechnolo...
# 1162  Dear Jack\nThanks a lot for your letter. I am ...
# 1281  Dear Mrs. Smith\nThank you very much for your ...
# 1282  Inventions have affected all our lives!\nWhat ...
# 1629  Dear Mr Redford,\nI'm writing to you to compla...
# 1630  In the future people will wear clothes made of...
# 1997  Modern technology has changed my daily life in...
# 2052  Dear Sir/Madam,\nI am writing to complaine abo...
# 2053  As we can understand by observing the fashion ...
# 2317  Dear Jane,\nI have read the advertisement for ...
# 2318  Dear John,\nHere in Brazil the rules at school...
# 2336  Long time ago, there were two brothers, whose ...
# 2383  Dear Ms. Jane Clark,\nI am writing to give my ...
# 2384  Money - hasn't it always been one of the most ...
# 2428  Dear Laurel,\nThank you for your recent letter...
#
#                                            mistakes_tag
# 308   [MJ, S, S, S, R, RD, U, FV, S, R, RA, RT, MP, ...
# 309   [RC, RP, ID, UY, L, RV, AGA, RN, MP, RD, RA, D...
# 390   [MP, RP, MP, RT, RP, R, S, RT, MP, DY, SX, MP,...
# 391   [MP, RP, R, MP, UP, MD, L, MP, RP, R, SA, FD, ...
# 392          [RV, UD, W, IV, RT, MT, M, RT, MD, RN, RT]
# 393                            [MY, MT, FV, IV, ID, SX]
# 997   [TV, AGV, RV, MP, MD, S, TV, TV, MD, TV, RV, U...
# 1111  [W, DJ, IN, CN, MP, AS, MP, AGN, RV, UQ, CN, F...
# 1162             [RP, AS, RP, L, RP, RN, RV, MP, S, MQ]
# 1281  [UP, UP, MC, RV, RT, W, RT, S, MP, MD, RP, MP,...
# 1282  [RA, MT, UP, MT, MP, RJ, AGN, M, S, RV, MT, TV...
# 1629          [RV, RV, RV, S, RT, AGD, AGN, MA, UA, RV]
# 1630         [S, RJ, RN, RV, RT, MP, MD, UT, RT, RT, R]
# 1997  [RT, FN, TV, UT, UA, UP, MD, UP, M, S, UD, MD,...
# 2052                        [S, RA, UA, MP, RD, RV, RV]
# 2053  [DY, RT, UT, RV, RN, S, RV, RV, S, UD, UY, RN,...
# 2317              [RV, FN, RA, AGV, TV, MT, MP, MP, FV]
# 2318                [AGV, RJ, RV, RP, S, DV, UP, RP, S]
# 2336  [MD, RY, MP, W, RY, RY, RT, RN, UV, MT, RN, RT...
# 2383            [MT, MV, UP, RJ, R, RP, MP, FN, RJ, TV]
# 2384  [AGN, S, ID, W, L, AGN, UT, RN, DJ, MD, S, MD,...
# 2428  [MV, S, MP, RT, UA, MP, CN, FV, AGA, RC, TV, M...

# %%
df.to_csv(f"data/fce.csv", index=False)
